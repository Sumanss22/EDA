# %% [markdown]
# # Forbes Richest Athletes

# %% [markdown]
# **Data Dictionary**
# 1. Name: Name of the athlete.
# 2. Nationality: Name of the country the athlete belongs to.
# 3. Current Rank: Rank in the corresponding Year.
# 4. Previous Year Rank: Rank in in the preceding year.
# 5. Sport: Name of the sports that athlete played that year.
# 6. Year: Current year of ranking.
# 7. earnings ( million) : Earnings of the athlete in millions in the corresponding year.

# %% [markdown]
# ### Read the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Forbes+Richest+Athletes+1990-2019.csv')

# %%
df.head()
# Out:
#                 Name Nationality  Current Rank Previous Year Rank  \
# 0         Mike Tyson         USA             1         Not Listed
# 1     Buster Douglas         USA             2         Not Listed
# 2  Sugar Ray Leonard         USA             3         Not Listed
# 3       Ayrton Senna      Brazil             4         Not Listed
# 4        Alain Prost      France             5         Not Listed
#
#          Sport  Year  earnings ($ million)
# 0       Boxing  1990                  28.6
# 1       Boxing  1990                  26.0
# 2       Boxing  1990                  13.0
# 3  Auto Racing  1990                  10.0
# 4  Auto Racing  1990                   9.0

# %%
df.shape
# Out:
# (291, 7)

# %%
df.isnull().sum()
# Out:
# Name                    0
# Nationality             0
# Current Rank            0
# Previous Year Rank      0
# Sport                   0
# Year                    0
# earnings ($ million)    0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                   Name Nationality  Current Rank Previous Year Rank  \
# count              291         291    291.000000                291
# unique              80          22           NaN                 12
# top     Michael Jordan         USA           NaN                >10
# freq                19         200           NaN                 90
# mean               NaN         NaN      5.446735                NaN
# std                NaN         NaN      2.850242                NaN
# min                NaN         NaN      1.000000                NaN
# 25%                NaN         NaN      3.000000                NaN
# 50%                NaN         NaN      5.000000                NaN
# 75%                NaN         NaN      8.000000                NaN
# max                NaN         NaN     10.000000                NaN
#
#              Sport         Year  earnings ($ million)
# count          291   291.000000            291.000000
# unique          14          NaN                   NaN
# top     Basketball          NaN                   NaN
# freq            79          NaN                   NaN
# mean           NaN  2004.611684             44.265292
# std            NaN     8.779899             33.212613
# min            NaN  1990.000000              8.100000
# 25%            NaN  1997.000000             23.500000
# 50%            NaN  2005.000000             38.000000
# 75%            NaN  2012.000000             54.650000
# max            NaN  2019.000000            300.000000

# %% [markdown]
# ### Q1. Atheletes from which country have been listed most number of times in the Forbes Richest Athletes from 1990 to 2019?

# %%
df.value_counts('Nationality').head()
# Out:
# Nationality
# USA            200
# Germany         13
# UK              13
# Switzerland     11
# Portugal         9
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='Nationality',order=df.value_counts('Nationality').index)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ### Q2. Make a plot visualizing year wise top earning (rank-1) athletes. In which year the rank 1 athlete earned the most? Which was the athlete who earned the most and what sport did he play? How much did the athlete earn?

# %%
df[df['Current Rank']==1]
sns.barplot(data=df[df['Current Rank']==1],x='Year',y='earnings ($ million)')
plt.xticks(rotation=70)
plt.show()

# %%
df[df['Current Rank']==1][df['Year']==2015]
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_15084\18398921.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Current Rank']==1][df['Year']==2015]
#                  Name Nationality  Current Rank Previous Year Rank   Sport  \
# 241  Floyd Mayweather         USA             1                  1  Boxing
#
#      Year  earnings ($ million)
# 241  2015                 300.0

# %% [markdown]
# ### Q3. Which athlete has been most frequently ranked number 1 from 1990 to 2019?

# %%
df.head(1)
# Out:
#          Name Nationality  Current Rank Previous Year Rank   Sport  Year  \
# 0  Mike Tyson         USA             1         Not Listed  Boxing  1990
#
#    earnings ($ million)
# 0                  28.6

# %%
df[df['Current Rank']==1].groupby('Name').count()
# Out:
#                     Nationality  Current Rank  Previous Year Rank  Sport  \
# Name
# Cristiano Ronaldo             2             2                   2      2
# Evander Holyfield             1             1                   1      1
# Floyd Mayweather              4             4                   4      4
# Lionel Messi                  1             1                   1      1
# Michael Jordan                6             6                   6      6
# Michael Schumacher            2             2                   2      2
# Mike Tyson                    2             2                   2      2
# Tiger Woods                  11            11                  11     11
#
#                     Year  earnings ($ million)
# Name
# Cristiano Ronaldo      2                     2
# Evander Holyfield      1                     1
# Floyd Mayweather       4                     4
# Lionel Messi           1                     1
# Michael Jordan         6                     6
# Michael Schumacher     2                     2
# Mike Tyson             2                     2
# Tiger Woods           11                    11

# %%
plt.pie(df[df['Current Rank']==1].value_counts('Name'),autopct='%.1f%%',labels=df[df['Current Rank']==1].value_counts('Name').index,
        explode=[0.2,0,0,0,0,0,0,0])
plt.show()

# %% [markdown]
# ### Q4. Players from which 2 sports have been listed least number of times in the Forbes RIchest Athletes List?

# %%
df.groupby('Sport').count()
# Out:
#                               Name  Nationality  Current Rank  \
# Sport
# American Football               18           18            18
# American Football / Baseball     1            1             1
# Auto Racing                     23           23            23
# Baseball                         6            6             6
# Basketball                      79           79            79
# Boxing                          46           46            46
# F1 racing                       13           13            13
# Golf                            43           43            43
# Ice Hockey                       4            4             4
# MMA                              1            1             1
# Soccer                          30           30            30
# Tennis                          22           22            22
# cycling                          1            1             1
# motorcycle gp                    4            4             4
#
#                               Previous Year Rank  Year  earnings ($ million)
# Sport
# American Football                             18    18                    18
# American Football / Baseball                   1     1                     1
# Auto Racing                                   23    23                    23
# Baseball                                       6     6                     6
# Basketball                                    79    79                    79
# Boxing                                        46    46                    46
# F1 racing                                     13    13                    13
# Golf                                          43    43                    43
# Ice Hockey                                     4     4                     4
# MMA                                            1     1                     1
# Soccer                                        30    30                    30
# Tennis                                        22    22                    22
# cycling                                        1     1                     1
# motorcycle gp                                  4     4                     4

# %%
sns.countplot(data=df,x='Sport',order=df.value_counts('Sport').index)
plt.xticks(rotation=90)
plt.show()

# %%
# Another method
sns.stripplot(data=df,x='Sport',y='earnings ($ million)')
plt.xticks(rotation=85)
plt.show()

# %% [markdown]
# ### Q5. Discuss the relationship between Current rank and earnings with the help of a suitable plot.

# %%
sns.boxplot(data=df,x='Current Rank',y='earnings ($ million)',showmeans=True)
plt.show()

# %% [markdown]
# ### Q6. Which three sports have the highest spread in terms of earnings (highest IQR)?

# %%
sns.boxplot(data=df,x='Sport',y='earnings ($ million)')
plt.xticks(rotation=85)
plt.show()

# %% [markdown]
# ### Q7. Show a trend in the positions at which Tiger Woods has appeared in the Forbes Richest Athletes list overs the years.

# %%
df[df['Name']=='Tiger Woods']
plt.figure(figsize=[15,4])
sns.lineplot(data=df[df['Name']=='Tiger Woods'],x='Year',y='Current Rank',markers=True)
plt.gca().invert_yaxis() # To Invert the labels on Y Axis
plt.xticks(np.arange(1997,2016))
plt.show()

# %% [markdown]
# ### Q8. Comment on the trend of the earnings of Tiger Woods overs the years.

# %%
plt.figure(figsize=[15,4])
sns.lineplot(data=df[df['Name']=='Tiger Woods'],x='Year',y='earnings ($ million)')
plt.xticks(np.arange(1997,2016))
plt.show()

# %% [markdown]
# ### Q9. Display the distribution of the earnings of Tiger Woods. Comment on how the distribution looks like and interpret some insights from the plot.

# %%
sns.histplot(data=df[df['Name']=='Tiger Woods'],x='earnings ($ million)',kde=True,bins=20)
plt.show()

# %% [markdown]
# ### Q10. Has the earnings of the richest athletes increased over the period of 30 years? Discuss the correlation between year and earnings.

# %%
sns.scatterplot(data=df,x='Year',y='earnings ($ million)')
plt.show()

# %% [markdown]
# ### Q-11 Display the earnings trend over the years.

# %%
sns.lineplot(data=df,x='Year',y='earnings ($ million)',errorbar=None,marker=True)
plt.xticks(np.arange(1990,2021),rotation=80)
plt.show()
